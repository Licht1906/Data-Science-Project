# %% [markdown]
# # 03 Feature Engineering
#
# Sanity check feature matrix dùng cho model.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from src.feature_engineering import build_features

engine = create_engine(os.getenv('TIKI_DATA_DB', 'postgresql+psycopg2://airflow:airflow@localhost:5432/tiki_data'))
df = pd.read_sql('''SELECT p.*, r.content, r.created_at, r.helpful_count, r.purchased FROM processed_reviews p JOIN raw_reviews r ON p.review_id = r.review_id''', engine)
features = build_features(df)
features.describe().T
